# %%
link = "https://www.bseindia.com/stock-share-price/{0}/{1}/{2}"
print(link.format("hello", "what", "are"))
# Out:
# https://www.bseindia.com/stock-share-price/hello/what/are

# %%
x = 'RELINFRA   INE036A01016   500390'
unclean = x.split(" ")
clean = [v for v in unclean if v != ""]
print(clean)
# Out:
# ['RELINFRA', 'INE036A01016', '500390']

# %%
with open("../../Data/RELIANCE INDUSTRIES LTD RELIANCE 500325 10_02_22.csv", 'r', encoding='utf-8') as file_read:
    data = file_read.readlines()
    
x = []
y = []
data.pop(0)
for i in data:
    x.append(i.replace('\n', '').split(",")[0])
    y.append(i.replace('\n', '').split(",")[1])
print(y)
# Out:
# ['2382.6', '2382.6', '2382.6', '2382.6', '2382.6', '2383.85', '2383.85', '2383.85', '2383.85', '2383.85', '2383.85', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2383.2', '2383.2', '2383.2', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2382.7', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.3', '2384.9', '2384.9', '2384.9', '2384.9', '2384.9', '2383.65', '2383.65', '2383.65', '2383.65', '2383.65', '2383.65', '2383.65', '2382.75', '2382.75', '2382.75', '2382.75', '2382.75', '2382.75', '2382.75', '2382.75', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.0', '2384.
# ...
